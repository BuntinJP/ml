# %%
import os
import pandas as pd
import numpy as np
import itertools
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,SimpleRNN
from tensorflow.keras.optimizers import Adam
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import seaborn as sns
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
# Out:
# 2023-11-06 07:20:29.816445: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 07:20:31.423361: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 07:20:31.424238: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-06 07:20:36.369693: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
DATA_DIR = './dms_data'
def load_and_preprocess_data(file_path):
    """CSVを読み込んでちょっと前処理する関数。"""
    df = pd.read_csv(file_path)
    df = df.drop(['timestamp'], axis=1)
    return df.dropna()

def get_data_from_directory(directory_path):
    """指定ディレクトリのCSV全部を読み込んで結合する関数。"""
    files = [f for f in os.listdir(directory_path) if f.endswith('.csv')]
    data_frames = [load_and_preprocess_data(os.path.join(directory_path, file)) for file in files]
    return pd.concat(data_frames, ignore_index=True)

def showLgbmModelFeature(model):
    plt.figure(figsize=(10,6))
    lgb.plot_importance(model)
    plt.show()

# トレインデータとテストデータを読み込む
train = get_data_from_directory(os.path.join(DATA_DIR, 'train'))
test = get_data_from_directory(os.path.join(DATA_DIR, 'test'))

# 特徴量を定義
features = [
    'm_speed', 'm_speed_var_480', 'm_speed_stddev_480', 'm_acceleration',
    'm_acceleration_var_480', 'm_acceleration_stddev_480', 'm_jerk',
    'm_jerk_var_480', 'm_jerk_stddev_480'
]

# %%
def evaluate_predictions(predicted_labels, true_labels):
    # Accuracy
    acc = accuracy_score(true_labels, predicted_labels)
    print(f"Accuracy: {acc:.4f}")
    
    # Confusion Matrix
    cm = confusion_matrix(true_labels, predicted_labels)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Other statistics (Precision, Recall, F1-score)
    print("\nClassification Report:\n")
    print(classification_report(true_labels, predicted_labels))

    return acc

# 使用例
# acc_value = evaluate_predictions(predicted_labels, y_test_oss)

# %%
# ossを丸めてint型として新しいカラムoss_intを追加
train['int_oss'] = train['oss'].round().astype(int)
train['int_sleepiness'] = train['Sleepiness'].round().astype(int)
test['int_oss'] = test['oss'].round().astype(int)
test['int_sleepiness'] = test['Sleepiness'].round().astype(int)

# %% [markdown]
# ### LightGBM

# %%
def train_lgbm_classificatoin(num_class,train,test):
    params = {
    'objective': 'multiclass', # 多クラス分類
    'num_class': num_class, # クラスの数
    'metric': 'multi_logloss' # 損失関数にmulti_loglossを使用
    }
    model = lgb.train(params, train, num_boost_round=1000, valid_sets=[train,test], early_stopping_rounds=10)
    return model

# %%
# int_oss
from sklearn.metrics import accuracy_score

X_train_oss = train.drop('int_oss', axis=1).drop('oss',axis=1)
y_train_oss = train['int_oss']
y_train_oss -= 1

X_test_oss = test.drop('int_oss', axis=1).drop('oss',axis=1)
y_test_oss = test['int_oss']
y_test_oss -= 1

train_data_oss = lgb.Dataset(X_train_oss, label=y_train_oss)
test_data_oss = lgb.Dataset(X_test_oss, label=y_test_oss, reference=train_data_oss)

model = train_lgbm_classificatoin(5,train_data_oss,test_data_oss)

y_pred_oss = model.predict(X_test_oss)
y_pred_oss_class = np.argmax(y_pred_oss,axis=1) + 1
y_test_oss += 1

acc = accuracy_score(y_test_oss,y_pred_oss_class)
print('Accuracy:', acc)
acc = evaluate_predictions(y_pred_oss_class, y_test_oss)
# Out:
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000636 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5462
# [LightGBM] [Info] Number of data points in the train set: 1738, number of used features: 24
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score -34.538776
# [LightGBM] [Info] Start training from score -1.491783
# [LightGBM] [Info] Start training from score -0.573959
# [LightGBM] [Info] Start training from score -1.847362
# [LightGBM] [Info] Start training from score -2.917196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	training's multi_logloss: 0.947342	valid_1's multi_logloss: 1.40269
# Training until validation scores don't improve for 10 rounds
# [2]	training's multi_logloss: 0.841149	valid_1's multi_logloss: 1.31846
# [3]	training's multi_logloss: 0.759124	valid_1's multi_logloss: 1.26255
# [4]	training's multi_logloss: 0.692617	valid_1's multi_logloss: 1.22125
# [5]	training's multi_logloss: 0.635017	valid_1's multi_logloss: 1.19163
# [6]	training's multi_logloss: 0.58521	valid_1's multi_logloss: 1.17507
# [7]	training's multi_logloss: 0.543466	valid_1's multi_logloss: 1.15447
# [8]	training's multi_logloss: 0.507324	valid_1's multi_logloss: 1.13956
# [9]	training's multi_logloss: 0.474801	valid_1's multi_logloss: 1.12649
# [10]	training's multi_logloss: 0.446421	valid_1's multi_logloss: 1.12369
# [11]	training's multi_logloss: 0.41965	valid_1's multi_logloss: 1.11458
# [12]	training's multi_logloss: 0.396115	valid_1's multi_logloss: 1.10781
# [13]	training's multi_logloss: 0.374696	valid_1's multi_logloss: 1.11017
# [14]	training's multi_logloss: 0.355285	valid_1's multi_logloss: 1.11078
# [15]	training's multi_logloss: 0.336967	valid_1's multi_logloss: 1.10866
# [16]	training's multi_logloss: 0.31967	valid_1's multi_logloss: 1.10268
# [17]	training's multi_logloss: 0.303928	valid_1's multi_logloss: 1.10041
# [18]	training's multi_logloss: 0.2893	valid_1's multi_logloss: 1.10071
# [19]	training's multi_logloss: 0.275803	valid_1's multi_logloss: 1.09243
# [20]	training's multi_logloss: 0.263185	valid_1's multi_logloss: 1.09086
# [21]	training's multi_logloss: 0.250646	valid_1's multi_logloss: 1.08728
# [22]	training's multi_logloss: 0.239579	valid_1's multi_logloss: 1.08749
# [23]	training's multi_logloss: 0.229009	valid_1's multi_logloss: 1.08671
# [24]	training's multi_logloss: 0.218274	valid_1's multi_logloss: 1.0845
# [25]	training's multi_logloss: 0.208142	valid_1's multi_logloss: 1.08513
# [26]	training's multi_logloss: 0.198423	valid_1's multi_logloss: 1.08686
# [27]	training's multi_logloss: 0.189649	valid_1's multi_logloss: 1.09029
# [28]	training's multi_logloss: 0.181366	valid_1's multi_logloss: 1.09096
# [29]	training's multi_logloss: 0.173902	valid_1's multi_logloss: 1.09112
# [30]	training's multi_logloss: 0.166884	valid_1's multi_logloss: 1.0911
# [31]	training's multi_logloss: 0.160313	valid_1's multi_logloss: 1.09243
# [32]	training's multi_logloss: 0.154033	valid_1's multi_logloss: 1.09804
# [33]	training's multi_logloss: 0.147687	valid_1's multi_logloss: 1.09912
# [34]	training's multi_logloss: 0.142098	valid_1's multi_logloss: 1.10359
# Early stopping, best iteration is:
# [24]	training's multi_logloss: 0.218274	valid_1's multi_logloss: 1.0845
# Accuracy: 0.6685185185185185
# Accuracy: 0.6685
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         5
#            2       0.72      0.70      0.71       161
#            3       0.69      0.77      0.73       257
#            4       0.51      0.55      0.53        78
#            5       0.53      0.21      0.30        39
#
#     accuracy                           0.67       540
#    macro avg       0.49      0.44      0.45       540
# weighted avg       0.66      0.67      0.66       540
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
showLgbmModelFeature(model)

# %%
# int_sleepinessに対するデータセット準備
X_train_sleepiness = train.drop('int_sleepiness', axis=1).drop('Sleepiness',axis=1)
y_train_sleepiness = train['int_sleepiness'] - 1

X_test_sleepiness = test.drop('int_sleepiness', axis=1).drop('Sleepiness',axis=1)
y_test_sleepiness = test['int_sleepiness'] - 1

train_data_sleepiness = lgb.Dataset(X_train_sleepiness, label=y_train_sleepiness)
test_data_sleepiness = lgb.Dataset(X_test_sleepiness, label=y_test_sleepiness, reference=train_data_sleepiness)

model = train_lgbm_classificatoin(9,train_data_sleepiness,test_data_sleepiness)

y_pred_sleepiness = model.predict(X_test_sleepiness)
y_pred_sleepiness_class = np.argmax(y_pred_sleepiness,axis=1) + 1
y_test_sleepiness += 1

acc = accuracy_score(y_test_sleepiness,y_pred_sleepiness_class)
print('Accuracy:', acc)
acc = evaluate_predictions(y_pred_sleepiness_class, y_test_sleepiness)
# Out:
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000414 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5458
# [LightGBM] [Info] Number of data points in the train set: 1738, number of used features: 24
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score -6.767343
# [LightGBM] [Info] Start training from score -3.528665
# [LightGBM] [Info] Start training from score -2.273104
# [LightGBM] [Info] Start training from score -1.733643
# [LightGBM] [Info] Start training from score -1.794064
# [LightGBM] [Info] Start training from score -1.794064
# [LightGBM] [Info] Start training from score -1.829279
# [LightGBM] [Info] Start training from score -2.094514
# [LightGBM] [Info] Start training from score -2.608460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	training's multi_logloss: 1.63602	valid_1's multi_logloss: 2.0964
# Training until validation scores don't improve for 10 rounds
# [2]	training's multi_logloss: 1.41264	valid_1's multi_logloss: 2.05239
# [3]	training's multi_logloss: 1.24362	valid_1's multi_logloss: 2.00614
# [4]	training's multi_logloss: 1.10982	valid_1's multi_logloss: 1.97314
# [5]	training's multi_logloss: 0.995317	valid_1's multi_logloss: 1.96106
# [6]	training's multi_logloss: 0.896911	valid_1's multi_logloss: 1.94556
# [7]	training's multi_logloss: 0.814734	valid_1's multi_logloss: 1.93113
# [8]	training's multi_logloss: 0.743094	valid_1's multi_logloss: 1.91649
# [9]	training's multi_logloss: 0.679756	valid_1's multi_logloss: 1.91187
# [10]	training's multi_logloss: 0.623384	valid_1's multi_logloss: 1.91094
# [11]	training's multi_logloss: 0.571639	valid_1's multi_logloss: 1.90805
# [12]	training's multi_logloss: 0.52754	valid_1's multi_logloss: 1.91046
# [13]	training's multi_logloss: 0.48506	valid_1's multi_logloss: 1.91008
# [14]	training's multi_logloss: 0.448467	valid_1's multi_logloss: 1.92082
# [15]	training's multi_logloss: 0.415103	valid_1's multi_logloss: 1.92668
# [16]	training's multi_logloss: 0.384198	valid_1's multi_logloss: 1.93713
# [17]	training's multi_logloss: 0.354219	valid_1's multi_logloss: 1.94906
# [18]	training's multi_logloss: 0.328728	valid_1's multi_logloss: 1.96384
# [19]	training's multi_logloss: 0.305038	valid_1's multi_logloss: 1.98344
# [20]	training's multi_logloss: 0.28442	valid_1's multi_logloss: 2.00028
# [21]	training's multi_logloss: 0.265093	valid_1's multi_logloss: 2.01281
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 0.571639	valid_1's multi_logloss: 1.90805
# Accuracy: 0.29814814814814816
# Accuracy: 0.2981
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         4
#            2       0.14      0.06      0.09        48
#            3       0.19      0.13      0.15        95
#            4       0.30      0.39      0.34        96
#            5       0.30      0.31      0.30        62
#            6       0.06      0.14      0.08        22
#            7       0.41      0.55      0.47        75
#            8       0.26      0.38      0.31        55
#            9       0.69      0.30      0.42        83
#
#     accuracy                           0.30       540
#    macro avg       0.26      0.25      0.24       540
# weighted avg       0.33      0.30      0.29       540

# %% [markdown]
# #
# | Model | Accuracy(OSS) | Accuracy(Sleepiness) |
# | --- | --- | ---|
# | LightGBM | 0.6685 | 0.4492 |
# | NN | 0.5291 | 0.2222 |
# | ランダムフォレスト |  0.6074   |   0.4412  |

# %% [markdown]
# | モデル名 | 平均 |
# | --- | --- |
# | lgbm | 0.6548 |
# | nn | 0.7912 |
# | linear_regression | 0.6949 |
# | svr |  0.7449|
# | random_forest | 0.7114 |

# %% [markdown]
# ### NeuralNetwork

# %%
# 1. データの準備
X_train_oss = train.drop('int_oss', axis=1).drop('oss',axis=1)
y_train_oss = train['int_oss']

X_test_oss = test.drop('int_oss', axis=1).drop('oss',axis=1)
y_test_oss = test['int_oss']


#1-5を0-4に
y_train_oss_adjusted = y_train_oss - 1
y_test_oss_adjusted = y_test_oss - 1

# ラベルをOne-Hotエンコーディング
num_class = 5
y_train_oss_cat = to_categorical(y_train_oss_adjusted, num_classes=num_class)
y_test_oss_cat = to_categorical(y_test_oss_adjusted, num_classes=num_class)

# 2. モデルの定義
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train_oss.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(num_class, activation='softmax')) 

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 3. モデルのトレーニング
history = model.fit(X_train_oss, y_train_oss_cat, epochs=50, batch_size=32, validation_split=0.2)

# 4. 評価
predictions = model.predict(X_test_oss)
predicted_labels = np.argmax(predictions, axis=1) + 1

# acc = np.mean(predicted_labels == y_test_oss)
# print('Accuracy:', acc)
acc = evaluate_predictions(predicted_labels, y_test_oss)
print(acc)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 1s 4ms/step - loss: 5.6445 - accuracy: 0.4676 - val_loss: 1.1891 - val_accuracy: 0.6322
# Epoch 2/50
# 44/44 [==============================] - 0s 1ms/step - loss: 1.2707 - accuracy: 0.5561 - val_loss: 1.5496 - val_accuracy: 0.4397
# Epoch 3/50
# 44/44 [==============================] - 0s 1ms/step - loss: 1.1200 - accuracy: 0.5741 - val_loss: 1.3394 - val_accuracy: 0.4023
# Epoch 4/50
# 44/44 [==============================] - 0s 1ms/step - loss: 1.0083 - accuracy: 0.5799 - val_loss: 1.7194 - val_accuracy: 0.3534
# Epoch 5/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9996 - accuracy: 0.5770 - val_loss: 1.1918 - val_accuracy: 0.4914
# Epoch 6/50
# 44/44 [==============================] - 0s 1ms/step - loss: 1.0206 - accuracy: 0.5863 - val_loss: 1.4478 - val_accuracy: 0.4195
# Epoch 7/50
# 44/44 [==============================] - 0s 1ms/step - loss: 1.0371 - accuracy: 0.5806 - val_loss: 1.3213 - val_accuracy: 0.4310
# Epoch 8/50
# 44/44 [==============================] - 0s 1ms/step - loss: 1.0187 - accuracy: 0.5942 - val_loss: 1.3181 - val_accuracy: 0.4195
# Epoch 9/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9842 - accuracy: 0.5986 - val_loss: 1.5794 - val_accuracy: 0.3822
# Epoch 10/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9215 - accuracy: 0.6201 - val_loss: 1.1901 - val_accuracy: 0.4626
# Epoch 11/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9442 - accuracy: 0.6115 - val_loss: 1.2442 - val_accuracy: 0.5086
# Epoch 12/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9120 - accuracy: 0.6165 - val_loss: 1.4448 - val_accuracy: 0.4167
# Epoch 13/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9524 - accuracy: 0.6108 - val_loss: 1.2530 - val_accuracy: 0.5000
# Epoch 14/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8449 - accuracy: 0.6259 - val_loss: 1.2717 - val_accuracy: 0.4828
# Epoch 15/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8600 - accuracy: 0.6338 - val_loss: 1.2959 - val_accuracy: 0.4454
# Epoch 16/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8853 - accuracy: 0.6288 - val_loss: 1.0549 - val_accuracy: 0.5718
# Epoch 17/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8571 - accuracy: 0.6396 - val_loss: 1.2518 - val_accuracy: 0.4856
# Epoch 18/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9322 - accuracy: 0.6180 - val_loss: 1.2133 - val_accuracy: 0.4914
# Epoch 19/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8515 - accuracy: 0.6453 - val_loss: 1.0321 - val_accuracy: 0.5345
# Epoch 20/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9400 - accuracy: 0.6216 - val_loss: 1.1779 - val_accuracy: 0.5431
# Epoch 21/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8857 - accuracy: 0.6266 - val_loss: 1.2676 - val_accuracy: 0.4885
# Epoch 22/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8417 - accuracy: 0.6245 - val_loss: 1.2522 - val_accuracy: 0.5086
# Epoch 23/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8077 - accuracy: 0.6460 - val_loss: 1.2430 - val_accuracy: 0.4540
# Epoch 24/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8474 - accuracy: 0.6317 - val_loss: 1.3137 - val_accuracy: 0.5000
# Epoch 25/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8278 - accuracy: 0.6424 - val_loss: 1.1430 - val_accuracy: 0.5057
# Epoch 26/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8180 - accuracy: 0.6345 - val_loss: 1.2870 - val_accuracy: 0.5029
# Epoch 27/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9114 - accuracy: 0.6115 - val_loss: 1.2321 - val_accuracy: 0.4943
# Epoch 28/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8388 - accuracy: 0.6518 - val_loss: 1.2275 - val_accuracy: 0.5287
# Epoch 29/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9260 - accuracy: 0.6324 - val_loss: 1.2462 - val_accuracy: 0.4914
# Epoch 30/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9722 - accuracy: 0.6237 - val_loss: 1.2488 - val_accuracy: 0.4971
# Epoch 31/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8216 - accuracy: 0.6446 - val_loss: 1.3975 - val_accuracy: 0.4540
# Epoch 32/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8588 - accuracy: 0.6288 - val_loss: 1.1831 - val_accuracy: 0.5431
# Epoch 33/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8480 - accuracy: 0.6360 - val_loss: 1.4771 - val_accuracy: 0.4339
# Epoch 34/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9277 - accuracy: 0.6259 - val_loss: 1.0176 - val_accuracy: 0.5632
# Epoch 35/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8297 - accuracy: 0.6489 - val_loss: 1.4560 - val_accuracy: 0.4425
# Epoch 36/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.9300 - accuracy: 0.6058 - val_loss: 1.0368 - val_accuracy: 0.5805
# Epoch 37/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8101 - accuracy: 0.6496 - val_loss: 1.2671 - val_accuracy: 0.5029
# Epoch 38/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.7943 - accuracy: 0.6388 - val_loss: 1.2561 - val_accuracy: 0.5374
# Epoch 39/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.7994 - accuracy: 0.6554 - val_loss: 1.2850 - val_accuracy: 0.4684
# Epoch 40/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8769 - accuracy: 0.6281 - val_loss: 1.2718 - val_accuracy: 0.4770
# Epoch 41/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8579 - accuracy: 0.6309 - val_loss: 1.2755 - val_accuracy: 0.5172
# Epoch 42/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8173 - accuracy: 0.6475 - val_loss: 1.1061 - val_accuracy: 0.5661
# Epoch 43/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8179 - accuracy: 0.6432 - val_loss: 1.1984 - val_accuracy: 0.5316
# Epoch 44/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8591 - accuracy: 0.6230 - val_loss: 0.9528 - val_accuracy: 0.5891
# Epoch 45/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.7625 - accuracy: 0.6590 - val_loss: 1.1971 - val_accuracy: 0.4943
# Epoch 46/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.7932 - accuracy: 0.6532 - val_loss: 1.4001 - val_accuracy: 0.4598
# Epoch 47/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8056 - accuracy: 0.6496 - val_loss: 1.0694 - val_accuracy: 0.5546
# Epoch 48/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.7916 - accuracy: 0.6554 - val_loss: 1.3418 - val_accuracy: 0.5201
# Epoch 49/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8686 - accuracy: 0.6367 - val_loss: 1.2947 - val_accuracy: 0.5201
# Epoch 50/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.8392 - accuracy: 0.6482 - val_loss: 0.9935 - val_accuracy: 0.5776
# 17/17 [==============================] - 0s 567us/step
# Accuracy: 0.1870
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            1       0.03      1.00      0.05         5
#            2       0.20      0.27      0.23       161
#            3       0.36      0.21      0.26       257
#            4       0.00      0.00      0.00        78
#            5       0.00      0.00      0.00        39
#
#     accuracy                           0.19       540
#    macro avg       0.12      0.29      0.11       540
# weighted avg       0.23      0.19      0.19       540
#
# 0.18703703703703703
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### ランダムフォレスト

# %%
def train_random_forest_classification(X_train, y_train):
    # ランダムフォレストのインスタンスを作成
    rf = RandomForestClassifier()
    # トレーニングデータでモデルをトレーニング
    rf.fit(X_train, y_train)
    return rf

# int_oss
rf_model_oss = train_random_forest_classification(X_train_oss, y_train_oss)
y_pred_rf_oss = rf_model_oss.predict(X_test_oss)
y_pred_rf_oss_class = y_pred_rf_oss + 1  # 1を足して元のラベルに戻す
acc_rf_oss = evaluate_predictions(y_pred_rf_oss_class, y_test_oss)

# int_sleepiness
rf_model_sleepiness = train_random_forest_classification(X_train_sleepiness, y_train_sleepiness)
y_pred_rf_sleepiness = rf_model_sleepiness.predict(X_test_sleepiness)
y_pred_rf_sleepiness_class = y_pred_rf_sleepiness + 1  # 1を足して元のラベルに戻す
acc_rf_sleepiness = evaluate_predictions(y_pred_rf_sleepiness_class, y_test_sleepiness)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/buntin/gits/ml/multiclass-classification.ipynb セル 15 line 9
#       <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     return rf
#       <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> # int_oss
# ----> <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> rf_model_oss = train_random_forest_classification(X_train_oss, y_train_oss)
#      <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> y_pred_rf_oss = rf_model_oss.predict(X_test_oss)
#      <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> y_pred_rf_oss_class = y_pred_rf_oss + 1  # 1を足して元のラベルに戻す
#
# /home/buntin/gits/ml/multiclass-classification.ipynb セル 15 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def train_random_forest_classification(X_train, y_train):
#       <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     # ランダムフォレストのインスタンスを作成
# ----> <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     rf = RandomForestClassifier()
#       <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     # トレーニングデータでモデルをトレーニング
#       <a href='vscode-notebook-cell://ssh-remote%2Brhel/home/buntin/gits/ml/multiclass-classification.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     rf.fit(X_train, y_train)
#
# NameError: name 'RandomForestClassifier' is not defined

# %% [markdown]
# ### GraphNeuralNetwork

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data

# %%
def read_and_process(directory):
    files = os.listdir(directory)
    df_list = []
    for file in files:
        if file.endswith('.csv'):
            df = pd.read_csv(os.path.join(directory, file))
            df = df.drop(['timestamp'], axis=1)
            df = df.dropna()
            df_list.append(df)
    df_combined = pd.concat(df_list, ignore_index=True)
    return df_combined

# %%
data_dir = 'dms_data'

train_data_path = data_dir + '/train'
test_data_path = data_dir + '/test'


train = read_and_process(train_data_path)
test = read_and_process(test_data_path)
features = ['m_speed', 'm_speed_var_480', 'm_speed_stddev_480', 'm_acceleration',
    'm_acceleration_var_480', 'm_acceleration_stddev_480', 'm_jerk',
    'm_jerk_var_480', 'm_jerk_stddev_480']

# %% [markdown]
# ### リカレントニューラルネットワーク(RNN)

# %%
rnn_model = Sequential()
rnn_model.add(SimpleRNN(64, activation='relu', input_shape=(X_train_oss.shape[1], 1)))
rnn_model.add(Dense(32, activation='relu'))
rnn_model.add(Dense(num_class, activation='softmax'))

rnn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

X_train_oss_rnn = X_train_oss.values.reshape(X_train_oss.shape[0], X_train_oss.shape[1], 1)

history = rnn_model.fit(X_train_oss_rnn, y_train_oss_cat, epochs=50, batch_size=32, validation_split=0.2)

X_test_oss_rnn = X_test_oss.values.reshape(X_test_oss.shape[0], X_test_oss.shape[1], 1)

predictions_rnn = rnn_model.predict(X_test_oss_rnn)
predicted_labels_rnn = np.argmax(predictions_rnn, axis=1) + 1

acc_rnn = evaluate_predictions(predicted_labels_rnn, y_test_oss)
print(acc_rnn)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 1s 8ms/step - loss: 1.1435 - accuracy: 0.5770 - val_loss: 1.2813 - val_accuracy: 0.4052
# Epoch 2/50
# 44/44 [==============================] - 0s 4ms/step - loss: 1.0104 - accuracy: 0.5935 - val_loss: 1.2131 - val_accuracy: 0.4511
# Epoch 3/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.9910 - accuracy: 0.5928 - val_loss: 1.1405 - val_accuracy: 0.4253
# Epoch 4/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.9361 - accuracy: 0.6223 - val_loss: 1.1048 - val_accuracy: 0.4167
# Epoch 5/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.9135 - accuracy: 0.6144 - val_loss: 0.9898 - val_accuracy: 0.4368
# Epoch 6/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.8656 - accuracy: 0.6259 - val_loss: 0.9660 - val_accuracy: 0.4770
# Epoch 7/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.8494 - accuracy: 0.6252 - val_loss: 0.8902 - val_accuracy: 0.5144
# Epoch 8/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.8239 - accuracy: 0.6381 - val_loss: 0.8220 - val_accuracy: 0.5632
# Epoch 9/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7783 - accuracy: 0.6619 - val_loss: 0.9380 - val_accuracy: 0.5000
# Epoch 10/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.8025 - accuracy: 0.6381 - val_loss: 0.8677 - val_accuracy: 0.5201
# Epoch 11/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7761 - accuracy: 0.6460 - val_loss: 0.8263 - val_accuracy: 0.5345
# Epoch 12/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7537 - accuracy: 0.6583 - val_loss: 0.8832 - val_accuracy: 0.5891
# Epoch 13/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7588 - accuracy: 0.6518 - val_loss: 0.8707 - val_accuracy: 0.5661
# Epoch 14/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7336 - accuracy: 0.6662 - val_loss: 0.7562 - val_accuracy: 0.6178
# Epoch 15/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7350 - accuracy: 0.6554 - val_loss: 0.9931 - val_accuracy: 0.5316
# Epoch 16/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7463 - accuracy: 0.6590 - val_loss: 0.9407 - val_accuracy: 0.5489
# Epoch 17/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7409 - accuracy: 0.6583 - val_loss: 0.8477 - val_accuracy: 0.6063
# Epoch 18/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7385 - accuracy: 0.6561 - val_loss: 1.1219 - val_accuracy: 0.4885
# Epoch 19/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7321 - accuracy: 0.6755 - val_loss: 0.7448 - val_accuracy: 0.5862
# Epoch 20/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7388 - accuracy: 0.6504 - val_loss: 0.8668 - val_accuracy: 0.5747
# Epoch 21/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7210 - accuracy: 0.6655 - val_loss: 0.8985 - val_accuracy: 0.5718
# Epoch 22/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7339 - accuracy: 0.6604 - val_loss: 0.7897 - val_accuracy: 0.6322
# Epoch 23/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7167 - accuracy: 0.6691 - val_loss: 0.9834 - val_accuracy: 0.5345
# Epoch 24/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7128 - accuracy: 0.6791 - val_loss: 0.8499 - val_accuracy: 0.5776
# Epoch 25/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7056 - accuracy: 0.6813 - val_loss: 0.9083 - val_accuracy: 0.5402
# Epoch 26/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7190 - accuracy: 0.6784 - val_loss: 0.8931 - val_accuracy: 0.5632
# Epoch 27/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7150 - accuracy: 0.6727 - val_loss: 1.0585 - val_accuracy: 0.5144
# Epoch 28/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7319 - accuracy: 0.6755 - val_loss: 0.9061 - val_accuracy: 0.5374
# Epoch 29/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7196 - accuracy: 0.6683 - val_loss: 0.9714 - val_accuracy: 0.5259
# Epoch 30/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7183 - accuracy: 0.6568 - val_loss: 0.9872 - val_accuracy: 0.5316
# Epoch 31/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7049 - accuracy: 0.6835 - val_loss: 0.8990 - val_accuracy: 0.5891
# Epoch 32/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7033 - accuracy: 0.6799 - val_loss: 0.8503 - val_accuracy: 0.5977
# Epoch 33/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7075 - accuracy: 0.6871 - val_loss: 0.9290 - val_accuracy: 0.5603
# Epoch 34/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.6967 - accuracy: 0.6842 - val_loss: 0.7741 - val_accuracy: 0.6236
# Epoch 35/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7004 - accuracy: 0.6734 - val_loss: 0.9251 - val_accuracy: 0.5575
# Epoch 36/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7290 - accuracy: 0.6640 - val_loss: 0.9305 - val_accuracy: 0.5201
# Epoch 37/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7093 - accuracy: 0.6712 - val_loss: 0.9026 - val_accuracy: 0.5575
# Epoch 38/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.6957 - accuracy: 0.6784 - val_loss: 0.9508 - val_accuracy: 0.5402
# Epoch 39/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.6953 - accuracy: 0.6935 - val_loss: 1.0823 - val_accuracy: 0.5029
# Epoch 40/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7004 - accuracy: 0.6734 - val_loss: 0.8408 - val_accuracy: 0.6178
# Epoch 41/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7048 - accuracy: 0.6849 - val_loss: 0.9065 - val_accuracy: 0.5718
# Epoch 42/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7132 - accuracy: 0.6619 - val_loss: 0.9171 - val_accuracy: 0.5805
# Epoch 43/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7238 - accuracy: 0.6741 - val_loss: 0.9358 - val_accuracy: 0.5805
# Epoch 44/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.6993 - accuracy: 0.6763 - val_loss: 0.9191 - val_accuracy: 0.5661
# Epoch 45/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7170 - accuracy: 0.6791 - val_loss: 0.9128 - val_accuracy: 0.5632
# Epoch 46/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7024 - accuracy: 0.6777 - val_loss: 0.8059 - val_accuracy: 0.5977
# Epoch 47/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 0.6878 - val_loss: 0.8327 - val_accuracy: 0.5948
# Epoch 48/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.6889 - accuracy: 0.6856 - val_loss: 0.9728 - val_accuracy: 0.5546
# Epoch 49/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.6905 - accuracy: 0.6899 - val_loss: 0.8970 - val_accuracy: 0.5690
# Epoch 50/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.7047 - accuracy: 0.6791 - val_loss: 0.8123 - val_accuracy: 0.6149
# 17/17 [==============================] - 0s 1ms/step
# Accuracy: 0.1389
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            1       0.03      1.00      0.05         5
#            2       0.17      0.25      0.20       161
#            3       0.24      0.11      0.15       257
#            4       0.60      0.04      0.07        78
#            5       0.00      0.00      0.00        39
#
#     accuracy                           0.14       540
#    macro avg       0.21      0.28      0.09       540
# weighted avg       0.25      0.14      0.14       540
#
# 0.1388888888888889
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/buntin/jupyter-env/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
