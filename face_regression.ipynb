# %%
import cv2
from matplotlib import pyplot as plt
import dlib
import numpy as np
import pandas as pd
import json
import os
import itertools
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

image_dir = 'face_data/pics/'
model = 'face_data/data/shape_predictor_68_face_landmarks.dat'

# %%
def load_and_preprocess_data(file_path):
  """CSVを読み込んで前処理する関数。"""
  df = pd.read_csv(file_path)
  df = df.drop(['timestamp'], axis=1)
  return df.dropna()


def get_data_from_directory(directory_path):
  """指定ディレクトリのCSV全部を読み込んで結合する関数。"""
  files = [f for f in os.listdir(directory_path) if f.endswith('.csv')]
  data_frames = [load_and_preprocess_data(os.path.join(directory_path, file)) for file in files]
  return pd.concat(data_frames, ignore_index=True)


def evaluate_model(model, X, y):
  """モデルの評価。RMSE"""
  predictions = model.predict(X)
  return np.sqrt(mean_squared_error(y, predictions))


def printResults(rmse_results, title, if_print=True):
  mean_rmse = np.mean(rmse_results)
  median_rmse = np.median(rmse_results)
  variance_rmse = np.var(rmse_results)
  std_rmse = np.std(rmse_results)
  min_rmse = np.min(rmse_results)
  max_rmse = np.max(rmse_results)

  out = ''
  out += f"[{title}]RMSEの平均値: {mean_rmse}\n"
  # out += f"[{title}]RMSEの中央値: {median_rmse}\n"
  # out += f"[{title}]RMSEの分散: {variance_rmse}\n"
  # out += f"[{title}]RMSEの標準偏差: {std_rmse}\n"
  out += f"[{title}]RMSEの最小値: {min_rmse}\n"
  out += f"[{title}]RMSEの最大値: {max_rmse}\n"

  if if_print:
    print(out)
  return out

  # print(f"[{title}]RMSEの平均値: {mean_rmse}")
  # # print(f"[{title}]RMSEの中央値: {median_rmse}")
  # # print(f"[{title}]RMSEの分散: {variance_rmse}")
  # # print(f"[{title}]RMSEの標準偏差: {std_rmse}")
  # print(f"[{title}]RMSEの最小値: {min_rmse}")
  # print(f"[{title}]RMSEの最大値: {max_rmse}")


def get_data_from_directory_with_scaling(directory_path, scaler=None):
  """指定ディレクトリのCSV全部を読み込んで結合し、スケーリングする関数。"""
  files = [f for f in os.listdir(directory_path) if f.endswith('.csv')]
  data_frames = [load_and_preprocess_data(os.path.join(directory_path, file)) for file in files]
  combined_df = pd.concat(data_frames, ignore_index=True)

  if scaler is not None:
    # 既存のスケーラーを使用してデータを変換
    combined_df[features] = scaler.transform(combined_df[features])
  else:
    # 新しいスケーラーをフィットしてデータを変換
    scaler = MinMaxScaler()
    combined_df[features] = scaler.fit_transform(combined_df[features])

  return combined_df, scaler

# %%
from sklearn.model_selection import KFold


def load_and_preprocess_data_save_timestamp(file_path):
  """CSVを読み込んで前処理する関数。"""
  df = pd.read_csv(file_path)
  return df.dropna()


def extract_image_name(timestamp):
  return timestamp.replace('-', '').replace(' ', '_').replace(':', '').replace('.', '_') + '.jpg'


def train_lightgbm_full(X, y):
  """Train LightGBM model on the full training data."""
  train_data = lgb.Dataset(X, label=y)
  params = {
      'objective': 'regression',
      'metric': 'rmse',
      'verbose': -1
  }
  model = lgb.train(params, train_data)
  return model


def evaluate_on_test(model, X_test, y_test):
  """Evaluate model on the test data."""
  predictions = model.predict(X_test)
  return np.sqrt(mean_squared_error(y_test, predictions))


def evaluate_with_kfold(X, y, n_splits=5):
  kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
  rmses = []

  for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    model = train_lightgbm_full(X_train, y_train)
    rmse = evaluate_on_test(model, X_test, y_test)
    rmses.append(rmse)

  return rmses


def add_eye_area_to_df(df, eye_areas):
  eye_areas_sum = []

  for _, row in df.iterrows():
    image_name = extract_image_name(row['timestamp'])
    eye_area = eye_areas.get(image_name, {})
    left_eye_area = eye_area.get('left_eye_area')
    right_eye_area = eye_area.get('right_eye_area')
    if left_eye_area is not None and right_eye_area is not None:
      try:
        eye_areas_sum.append(float(left_eye_area) + float(right_eye_area))
      except ValueError:
        eye_areas_sum.append(np.nan)
    else:
      eye_areas_sum.append(np.nan)
  df['eye_area_sum'] = eye_areas_sum
  return df

# %%
def solve_one_subject(csv_filepath, json_filepath, descrive=False, data_name=""):
  # 特徴量を定義
  features = [
      'm_speed', 'm_speed_var_480', 'm_speed_stddev_480', 'm_acceleration',
      'm_acceleration_var_480', 'm_acceleration_stddev_480', 'm_jerk',
      'm_jerk_var_480', 'm_jerk_stddev_480', 'oss', 'Sleepiness'
  ]
  outStr = "train,test同時に正規化\n"

  data = load_and_preprocess_data_save_timestamp(csv_filepath)
  with open(json_filepath, 'r') as f:
    eye_areas = json.load(f)
  data = add_eye_area_to_df(data, eye_areas)
  features.append('eye_area_sum')
  # 正規化
  scaler = MinMaxScaler()
  data[features] = scaler.fit_transform(data[features])

  X = data[features]
  Y_oss = data['oss']
  Y_Sleepiness = data['Sleepiness']
  if (descrive):
    print(data.describe())

  oss_kfold_rmses_norm_divided = evaluate_with_kfold(X, Y_oss)
  outStr += printResults(oss_kfold_rmses_norm_divided, "lgbm-oss-normalized-kfold-single-sbj", False)

  sleepiness_kfold_rmses_norm_divided = evaluate_with_kfold(X, Y_Sleepiness)
  outStr += printResults(sleepiness_kfold_rmses_norm_divided, "lgbm-sleepiness-normalized-kfold-single-sbj", False)
  return {'out': outStr, 'oss': oss_kfold_rmses_norm_divided, 'sleepiness': sleepiness_kfold_rmses_norm_divided}

# %%
DATA_DIR = 'dms_data_single'
EYE_DATA_DIR = 'eye_data_json_dir'
file_names = [
    "20201126_1546_0_y",
    "20201127_1432_7_y",
    "20201127_1548_2_y",
    "20201127_1701_7_y",
    "20201127_1840_5_y",
    "20201130_1122_5_y",
    "20201130_1808_6_y",
    "20201201_1230_0_y",
    "20201201_1429_5_y",
    "20201201_1555_0_y",
    "20201203_1022_7_y",
    "20201203_1244_5_y",
    "20201203_1404_6_y",
    "20201210_1112_2_y",
    "20201210_1354_2_y",
    "20201210_1610_6_y"
]
data_name = file_names[0]
csv_filename = f'{data_name}.csv'
json_filename = f'{data_name}_eye_areas.json'
csv_filepath = os.path.join(DATA_DIR, csv_filename)
json_filepath = os.path.join(EYE_DATA_DIR, json_filename)


print(solve_one_subject(csv_filepath, json_filepath)['out'])
# Out:
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.052189182576800365
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03686978680807165
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.06516212156327408
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.0538552717810238
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.03667714228659573
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.07357452653473572

# %%
file_names = [
    "20201126_1546_0_y",
    "20201127_1432_7_y",
    "20201127_1548_2_y",
    "20201127_1701_7_y",
    "20201127_1840_5_y",
    "20201130_1122_5_y",
    "20201130_1808_6_y",
    "20201201_1230_0_y",
    "20201201_1429_5_y",
    "20201201_1555_0_y",
    "20201203_1022_7_y",
    "20201203_1244_5_y",
    "20201203_1404_6_y",
    "20201210_1112_2_y",
    "20201210_1354_2_y",
    "20201210_1610_6_y"
]
oss_rmses = []
Sleepiness_rmses = []

for data_name in file_names:
  print(data_name)
  csv_filename = f'{data_name}.csv'
  json_filename = f'{data_name}_eye_areas.json'
  csv_filepath = os.path.join(DATA_DIR, csv_filename)
  json_filepath = os.path.join(EYE_DATA_DIR, json_filename)
  result = solve_one_subject(csv_filepath, json_filepath, data_name=data_name)
  print(result['out'])
  oss_rmses.append(result['oss'])
  Sleepiness_rmses.append(result['sleepiness'])
print(printResults(oss_rmses, "lgbm-oss-normalized-kfold-all-sbj"))
print(printResults(Sleepiness_rmses, "lgbm-sleepiness-normalized-kfold-all-sbj"))
# Out:
# 20201126_1546_0_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.052189182576800365
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03686978680807165
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.06516212156327408
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.0538552717810238
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.03667714228659573
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.07357452653473572
#
# 20201127_1432_7_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.06465127581042733
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.04558136893327791
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.08557951487362439
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.029401891072867913
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.017283799508294524
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.04103543244844021
#
# 20201127_1548_2_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.05852087096473546
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03699811603646965
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.07837976489663528
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.047406678477545566
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.031331370648692555
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.0725617987156643
#
# 20201127_1701_7_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.053841506561449835
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03934106297674542
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.09566507807009009
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.03536262280293504
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.023338409568986432
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.049352315949966905
#
# 20201127_1840_5_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.058367569021216106
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03229442925327197
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.07408583923278385
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.07014647036481857
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.044718675094615586
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.08155714167933562
#
# 20201130_1122_5_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.0990536053375453
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.07591204622962396
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.12360976063399526
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.11222191942698463
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.09984293793990662
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.1522191903346623
#
# 20201130_1808_6_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.042765048334848045
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03711622482659978
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.05549640918260373
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.036036372735739765
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.021509802527038564
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.07005042706909637
#
# 20201201_1230_0_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.043448769546298276
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03280829118000899
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.0616958964266534
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.02981944534622799
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.016281018848774986
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.048859413981514985
#
# 20201201_1429_5_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.05827177170410821
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.04064999832042917
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.07802633252237927
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.06149958499061185
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.049578344250900026
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.08493060786588766
#
# 20201201_1555_0_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.05922150519115514
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03901131525144376
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.07532648556762749
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.049376014653104046
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.03002596912024894
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.06588489758637903
#
# 20201203_1022_7_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.027891004525473533
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.02201128309601516
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.04769511008135491
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.1364002075622409
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.10081964743905426
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.19150354939247907
#
# 20201203_1244_5_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.060799257423942286
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.02960109628253921
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.09527132191812973
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.05146150701582902
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.030029525822062617
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.06299476457894468
#
# 20201203_1404_6_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.04534160514529867
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03360658715772611
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.061580935268038046
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.037478700979402826
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.029985615552425432
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.047122374193178274
#
# 20201210_1112_2_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.05721907583422377
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.03558774863075635
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.07961517270627891
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.03669436979496037
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.022184015969152922
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.06573161862266996
#
# 20201210_1354_2_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.08046948849626627
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.07040256817959788
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.09742315785546427
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.07134446707267843
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.05635778591655735
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.0875235105628319
#
# 20201210_1610_6_y
# train,test同時に正規化
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの平均値: 0.04107953883827355
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最小値: 0.024636081154882788
# [lgbm-oss-normalized-kfold-single-sbj]RMSEの最大値: 0.05811811861688027
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの平均値: 0.05227682645948907
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最小値: 0.04155862894906558
# [lgbm-sleepiness-normalized-kfold-single-sbj]RMSEの最大値: 0.06970097106687913
#
# [lgbm-oss-normalized-kfold-all-sbj]RMSEの平均値: 0.056445692207003885
# [lgbm-oss-normalized-kfold-all-sbj]RMSEの最小値: 0.02201128309601516
# [lgbm-oss-normalized-kfold-all-sbj]RMSEの最大値: 0.12360976063399526
#
# [lgbm-oss-normalized-kfold-all-sbj]RMSEの平均値: 0.056445692207003885
# [lgbm-oss-normalized-kfold-all-sbj]RMSEの最小値: 0.02201128309601516
# [lgbm-oss-normalized-kfold-all-sbj]RMSEの最大値: 0.12360976063399526
#
# [lgbm-sleepiness-normalized-kfold-all-sbj]RMSEの平均値: 0.05692389690852874
# [lgbm-sleepiness-normalized-kfold-all-sbj]RMSEの最小値: 0.016281018848774986
# [lgbm-sleepiness-normalized-kfold-all-sbj]RMSEの最大値: 0.19150354939247907
#
# [lgbm-sleepiness-normalized-kfold-all-sbj]RMSEの平均値: 0.05692389690852874
# [lgbm-sleepiness-normalized-kfold-all-sbj]RMSEの最小値: 0.016281018848774986
# [lgbm-sleepiness-normalized-kfold-all-sbj]RMSEの最大値: 0.19150354939247907
